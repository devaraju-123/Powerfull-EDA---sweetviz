# %% [markdown]
# ###### Powerful EDA

# %%
import sweetviz
import pandas as pd

# %%
train = pd.read_csv('House_train.csv')

# %%
test = pd.read_csv('House_test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
my_report = sweetviz.analyze([train,'Train'],target_feat='SalePrice')
# Out:
# :FEATURES DONE:                    |█████████████████████| [100%]   01:10  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:13  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
my_report.show_html('Report.html')
# Out:
# Report Report.html was generated! NOTEBOOK/COLAB USERS: no browser will pop up, the report is saved in your notebook/colab files.

# %%
## comparing tow dataframes ( test vs train data sets)

# %%
my_report1 = sweetviz.compare([train, 'Train'],[test, 'Test'], 'SalePrice')
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |▎                    | [  1%]   00:00  -> (00:09 left)
# :TARGET::                          |▎                    | [  1%]   00:00  -> (00:09 left)
# :TARGET::                          |▌                    | [  2%]   00:00  -> (00:25 left)
# :Id:                               |▌                    | [  2%]   00:00  -> (00:25 left)
# :Id:                               |▊                    | [  4%]   00:02  -> (00:52 left)
# :MSSubClass:                       |▊                    | [  4%]   00:02  -> (00:52 left)
# :MSSubClass:                       |█                    | [  5%]   00:04  -> (01:16 left)
# :MSZoning:                         |█                    | [  5%]   00:04  -> (01:16 left)
# :MSZoning:                         |█▎                   | [  6%]   00:05  -> (01:14 left)
# :LotFrontage:                      |█▎                   | [  6%]   00:05  -> (01:14 left)
# :LotFrontage:                      |█▌                   | [  7%]   00:06  -> (01:26 left)
# :LotArea:                          |█▌                   | [  7%]   00:06  -> (01:26 left)
# :LotArea:                          |█▊                   | [  9%]   00:07  -> (01:30 left)
# :Street:                           |█▊                   | [  9%]   00:07  -> (01:30 left)
# :Street:                           |██                   | [ 10%]   00:08  -> (01:16 left)
# :Alley:                            |██                   | [ 10%]   00:08  -> (01:16 left)
# :Alley:                            |██▎                  | [ 11%]   00:09  -> (01:09 left)
# :LotShape:                         |██▎                  | [ 11%]   00:09  -> (01:09 left)
# :LotShape:                         |██▌                  | [ 12%]   00:10  -> (01:04 left)
# :LandContour:                      |██▌                  | [ 12%]   00:10  -> (01:04 left)
# :LandContour:                      |██▊                  | [ 13%]   00:10  -> (01:01 left)
# :Utilities:                        |██▊                  | [ 13%]   00:10  -> (01:01 left)
# :Utilities:                        |███                  | [ 15%]   00:11  -> (00:56 left)
# :LotConfig:                        |███                  | [ 15%]   00:11  -> (00:56 left)
# :LotConfig:                        |███▎                 | [ 16%]   00:12  -> (00:57 left)
# :LandSlope:                        |███▎                 | [ 16%]   00:12  -> (00:57 left)
# :LandSlope:                        |███▌                 | [ 17%]   00:13  -> (00:54 left)
# :Neighborhood:                     |███▌                 | [ 17%]   00:13  -> (00:54 left)
# :Neighborhood:                     |███▊                 | [ 18%]   00:14  -> (00:57 left)
# :Condition1:                       |███▊                 | [ 18%]   00:14  -> (00:57 left)
# :Condition1:                       |████                 | [ 20%]   00:15  -> (00:56 left)
# :Condition2:                       |████                 | [ 20%]   00:15  -> (00:56 left)
# :Condition2:                       |████▎                | [ 21%]   00:16  -> (00:59 left)
# :BldgType:                         |████▎                | [ 21%]   00:16  -> (00:59 left)
# :BldgType:                         |████▌                | [ 22%]   00:16  -> (00:56 left)
# :HouseStyle:                       |████▌                | [ 22%]   00:16  -> (00:56 left)
# :HouseStyle:                       |████▊                | [ 23%]   00:19  -> (01:26 left)
# :OverallQual:                      |████▊                | [ 23%]   00:19  -> (01:26 left)
# :OverallQual:                      |█████                | [ 24%]   00:20  -> (01:13 left)
# :OverallCond:                      |█████                | [ 24%]   00:20  -> (01:13 left)
# :OverallCond:                      |█████▍               | [ 26%]   00:21  -> (01:08 left)
# :YearBuilt:                        |█████▍               | [ 26%]   00:21  -> (01:08 left)
# :YearBuilt:                        |█████▋               | [ 27%]   00:22  -> (01:12 left)
# :YearRemodAdd:                     |█████▋               | [ 27%]   00:22  -> (01:12 left)
# :YearRemodAdd:                     |█████▉               | [ 28%]   00:23  -> (01:15 left)
# :RoofStyle:                        |█████▉               | [ 28%]   00:23  -> (01:15 left)
# :RoofStyle:                        |██████▏              | [ 29%]   00:24  -> (01:05 left)
# :RoofMatl:                         |██████▏              | [ 29%]   00:24  -> (01:05 left)
# :RoofMatl:                         |██████▍              | [ 30%]   00:25  -> (00:58 left)
# :Exterior1st:                      |██████▍              | [ 30%]   00:25  -> (00:58 left)
# :Exterior1st:                      |██████▋              | [ 32%]   00:26  -> (00:54 left)
# :Exterior2nd:                      |██████▋              | [ 32%]   00:26  -> (00:54 left)
# :Exterior2nd:                      |██████▉              | [ 33%]   00:27  -> (00:51 left)
# :MasVnrType:                       |██████▉              | [ 33%]   00:27  -> (00:51 left)
# :MasVnrType:                       |███████▏             | [ 34%]   00:27  -> (00:45 left)
# :MasVnrArea:                       |███████▏             | [ 34%]   00:27  -> (00:45 left)
# :MasVnrArea:                       |███████▍             | [ 35%]   00:29  -> (00:55 left)
# :ExterQual:                        |███████▍             | [ 35%]   00:29  -> (00:55 left)
# :ExterQual:                        |███████▋             | [ 37%]   00:30  -> (00:49 left)
# :ExterCond:                        |███████▋             | [ 37%]   00:30  -> (00:49 left)
# :ExterCond:                        |███████▉             | [ 38%]   00:31  -> (00:48 left)
# :Foundation:                       |███████▉             | [ 38%]   00:31  -> (00:48 left)
# :Foundation:                       |████████▏            | [ 39%]   00:31  -> (00:46 left)
# :BsmtQual:                         |████████▏            | [ 39%]   00:31  -> (00:46 left)
# :BsmtQual:                         |████████▍            | [ 40%]   00:32  -> (00:41 left)
# :BsmtCond:                         |████████▍            | [ 40%]   00:32  -> (00:41 left)
# :BsmtCond:                         |████████▋            | [ 41%]   00:33  -> (00:36 left)
# :BsmtExposure:                     |████████▋            | [ 41%]   00:33  -> (00:36 left)
# :BsmtExposure:                     |████████▉            | [ 43%]   00:33  -> (00:36 left)
# :BsmtFinType1:                     |████████▉            | [ 43%]   00:33  -> (00:36 left)
# :BsmtFinType1:                     |█████████▏           | [ 44%]   00:34  -> (00:37 left)
# :BsmtFinSF1:                       |█████████▏           | [ 44%]   00:34  -> (00:37 left)
# :BsmtFinSF1:                       |█████████▍           | [ 45%]   00:37  -> (00:55 left)
# :BsmtFinType2:                     |█████████▍           | [ 45%]   00:37  -> (00:55 left)
# :BsmtFinType2:                     |█████████▋           | [ 46%]   00:37  -> (00:47 left)
# :BsmtFinSF2:                       |█████████▋           | [ 46%]   00:37  -> (00:47 left)
# :BsmtFinSF2:                       |█████████▉           | [ 48%]   00:39  -> (00:49 left)
# :BsmtUnfSF:                        |█████████▉           | [ 48%]   00:39  -> (00:49 left)
# :BsmtUnfSF:                        |██████████▏          | [ 49%]   00:40  -> (00:50 left)
# :TotalBsmtSF:                      |██████████▏          | [ 49%]   00:40  -> (00:50 left)
# :TotalBsmtSF:                      |██████████▌          | [ 50%]   00:41  -> (00:50 left)
# :Heating:                          |██████████▌          | [ 50%]   00:41  -> (00:50 left)
# :Heating:                          |██████████▊          | [ 51%]   00:42  -> (00:42 left)
# :HeatingQC:                        |██████████▊          | [ 51%]   00:42  -> (00:42 left)
# :HeatingQC:                        |███████████          | [ 52%]   00:43  -> (00:38 left)
# :CentralAir:                       |███████████          | [ 52%]   00:43  -> (00:38 left)
# :CentralAir:                       |███████████▎         | [ 54%]   00:44  -> (00:36 left)
# :Electrical:                       |███████████▎         | [ 54%]   00:44  -> (00:36 left)
# :Electrical:                       |███████████▌         | [ 55%]   00:44  -> (00:32 left)
# :1stFlrSF:                         |███████████▌         | [ 55%]   00:44  -> (00:32 left)
# :1stFlrSF:                         |███████████▊         | [ 56%]   00:46  -> (00:37 left)
# :2ndFlrSF:                         |███████████▊         | [ 56%]   00:46  -> (00:37 left)
# :2ndFlrSF:                         |████████████         | [ 57%]   00:47  -> (00:42 left)
# :LowQualFinSF:                     |████████████         | [ 57%]   00:47  -> (00:42 left)
# :LowQualFinSF:                     |████████████▎        | [ 59%]   00:49  -> (00:44 left)
# :GrLivArea:                        |████████████▎        | [ 59%]   00:49  -> (00:44 left)
# :GrLivArea:                        |████████████▌        | [ 60%]   00:50  -> (00:45 left)
# :BsmtFullBath:                     |████████████▌        | [ 60%]   00:50  -> (00:45 left)
# :BsmtFullBath:                     |████████████▊        | [ 61%]   00:51  -> (00:38 left)
# :BsmtHalfBath:                     |████████████▊        | [ 61%]   00:51  -> (00:38 left)
# :BsmtHalfBath:                     |█████████████        | [ 62%]   00:52  -> (00:32 left)
# :FullBath:                         |█████████████        | [ 62%]   00:52  -> (00:32 left)
# :FullBath:                         |█████████████▎       | [ 63%]   00:52  -> (00:27 left)
# :HalfBath:                         |█████████████▎       | [ 63%]   00:52  -> (00:27 left)
# :HalfBath:                         |█████████████▌       | [ 65%]   00:53  -> (00:24 left)
# :BedroomAbvGr:                     |█████████████▌       | [ 65%]   00:53  -> (00:24 left)
# :BedroomAbvGr:                     |█████████████▊       | [ 66%]   00:55  -> (00:33 left)
# :KitchenAbvGr:                     |█████████████▊       | [ 66%]   00:55  -> (00:33 left)
# :KitchenAbvGr:                     |██████████████       | [ 67%]   00:56  -> (00:30 left)
# :KitchenQual:                      |██████████████       | [ 67%]   00:56  -> (00:30 left)
# :KitchenQual:                      |██████████████▎      | [ 68%]   00:57  -> (00:26 left)
# :TotRmsAbvGrd:                     |██████████████▎      | [ 68%]   00:57  -> (00:26 left)
# :TotRmsAbvGrd:                     |██████████████▌      | [ 70%]   00:58  -> (00:28 left)
# :Functional:                       |██████████████▌      | [ 70%]   00:58  -> (00:28 left)
# :Functional:                       |██████████████▊      | [ 71%]   00:59  -> (00:25 left)
# :Fireplaces:                       |██████████████▊      | [ 71%]   00:59  -> (00:25 left)
# :Fireplaces:                       |███████████████      | [ 72%]   01:00  -> (00:23 left)
# :FireplaceQu:                      |███████████████      | [ 72%]   01:00  -> (00:23 left)
# :FireplaceQu:                      |███████████████▎     | [ 73%]   01:01  -> (00:21 left)
# :GarageType:                       |███████████████▎     | [ 73%]   01:01  -> (00:21 left)
# :GarageType:                       |███████████████▌     | [ 74%]   01:02  -> (00:19 left)
# :GarageYrBlt:                      |███████████████▌     | [ 74%]   01:02  -> (00:19 left)
# :GarageYrBlt:                      |███████████████▉     | [ 76%]   01:03  -> (00:22 left)
# :GarageFinish:                     |███████████████▉     | [ 76%]   01:03  -> (00:22 left)
# :GarageFinish:                     |████████████████▏    | [ 77%]   01:04  -> (00:19 left)
# :GarageCars:                       |████████████████▏    | [ 77%]   01:04  -> (00:19 left)
# :GarageCars:                       |████████████████▍    | [ 78%]   01:05  -> (00:18 left)
# :GarageArea:                       |████████████████▍    | [ 78%]   01:05  -> (00:18 left)
# :GarageArea:                       |████████████████▋    | [ 79%]   01:07  -> (00:20 left)
# :GarageQual:                       |████████████████▋    | [ 79%]   01:07  -> (00:20 left)
# :GarageQual:                       |████████████████▉    | [ 80%]   01:08  -> (00:17 left)
# :GarageCond:                       |████████████████▉    | [ 80%]   01:08  -> (00:17 left)
# :GarageCond:                       |█████████████████▏   | [ 82%]   01:08  -> (00:14 left)
# :PavedDrive:                       |█████████████████▏   | [ 82%]   01:08  -> (00:14 left)
# :PavedDrive:                       |█████████████████▍   | [ 83%]   01:09  -> (00:12 left)
# :WoodDeckSF:                       |█████████████████▍   | [ 83%]   01:09  -> (00:12 left)
# :WoodDeckSF:                       |█████████████████▋   | [ 84%]   01:11  -> (00:14 left)
# :OpenPorchSF:                      |█████████████████▋   | [ 84%]   01:11  -> (00:14 left)
# :OpenPorchSF:                      |█████████████████▉   | [ 85%]   01:12  -> (00:14 left)
# :EnclosedPorch:                    |█████████████████▉   | [ 85%]   01:12  -> (00:14 left)
# :EnclosedPorch:                    |██████████████████▏  | [ 87%]   01:14  -> (00:14 left)
# :3SsnPorch:                        |██████████████████▏  | [ 87%]   01:14  -> (00:14 left)
# :3SsnPorch:                        |██████████████████▍  | [ 88%]   01:15  -> (00:14 left)
# :ScreenPorch:                      |██████████████████▍  | [ 88%]   01:15  -> (00:14 left)
# :ScreenPorch:                      |██████████████████▋  | [ 89%]   01:17  -> (00:12 left)
# :PoolArea:                         |██████████████████▋  | [ 89%]   01:17  -> (00:12 left)
# :PoolArea:                         |██████████████████▉  | [ 90%]   01:18  -> (00:10 left)
# :PoolQC:                           |██████████████████▉  | [ 90%]   01:18  -> (00:10 left)
# :Fence:                            |███████████████████▏ | [ 91%]   01:18  -> (00:09 left)
# :Fence:                            |███████████████████▍ | [ 93%]   01:19  -> (00:06 left)
# :MiscFeature:                      |███████████████████▍ | [ 93%]   01:19  -> (00:06 left)
# :MiscFeature:                      |███████████████████▋ | [ 94%]   01:20  -> (00:05 left)
# :MiscVal:                          |███████████████████▋ | [ 94%]   01:20  -> (00:05 left)
# :MiscVal:                          |███████████████████▉ | [ 95%]   01:23  -> (00:06 left)
# :MoSold:                           |███████████████████▉ | [ 95%]   01:23  -> (00:06 left)
# :MoSold:                           |████████████████████▏| [ 96%]   01:25  -> (00:05 left)
# :YrSold:                           |████████████████████▏| [ 96%]   01:25  -> (00:05 left)
# :YrSold:                           |████████████████████▍| [ 98%]   01:26  -> (00:02 left)
# :SaleType:                         |████████████████████▍| [ 98%]   01:26  -> (00:02 left)
# :SaleType:                         |████████████████████▋| [ 99%]   01:27  -> (00:01 left)
# :SaleCondition:                    |████████████████████▋| [ 99%]   01:27  -> (00:01 left)
# :SaleCondition:                    |█████████████████████| [100%]   01:28  -> (00:00 left)
# :FEATURES DONE:                    |█████████████████████| [100%]   01:28  -> (00:00 left)
#
#                                    |                         | [  0%]   00:00  -> (? left)
# :Processing Pairwise Features:     |                         | [  0%]   00:00  -> (? left)
# :Processing Pairwise Features:     |█                    | [  5%]   00:00  -> (00:10 left)
# :Processing Pairwise Features:     |█▊                   | [  9%]   00:01  -> (00:11 left)
# :Processing Pairwise Features:     |██                   | [ 10%]   00:01  -> (00:22 left)
# :Processing Pairwise Features:     |██▎                  | [ 11%]   00:02  -> (00:27 left)
# :Processing Pairwise Features:     |██▌                  | [ 12%]   00:02  -> (00:32 left)
# :Processing Pairwise Features:     |██▊                  | [ 14%]   00:03  -> (00:35 left)
# :Processing Pairwise Features:     |███                  | [ 15%]   00:04  -> (00:34 left)
# :Processing Pairwise Features:     |███▎                 | [ 16%]   00:04  -> (00:32 left)
# :Processing Pairwise Features:     |███▋                 | [ 17%]   00:04  -> (00:32 left)
# :Processing Pairwise Features:     |███▉                 | [ 19%]   00:05  -> (00:39 left)
# :Processing Pairwise Features:     |████▏                | [ 20%]   00:06  -> (00:37 left)
# :Processing Pairwise Features:     |████▍                | [ 21%]   00:06  -> (00:35 left)
# :Processing Pairwise Features:     |████▋                | [ 22%]   00:07  -> (00:35 left)
# :Processing Pairwise Features:     |████▉                | [ 23%]   00:08  -> (00:38 left)
# :Processing Pairwise Features:     |█████▏               | [ 25%]   00:08  -> (00:37 left)
# :Processing Pairwise Features:     |█████▉               | [ 28%]   00:09  -> (00:28 left)
# :Processing Pairwise Features:     |██████▏              | [ 30%]   00:09  -> (00:29 left)
# :Processing Pairwise Features:     |██████▍              | [ 31%]   00:10  -> (00:27 left)
# :Processing Pairwise Features:     |██████▋              | [ 32%]   00:10  -> (00:26 left)
# :Processing Pairwise Features:     |███████              | [ 33%]   00:11  -> (00:24 left)
# :Processing Pairwise Features:     |███████▌             | [ 36%]   00:11  -> (00:21 left)
# :Processing Pairwise Features:     |███████▊             | [ 37%]   00:12  -> (00:22 left)
# :Processing Pairwise Features:     |████████             | [ 38%]   00:12  -> (00:23 left)
# :Processing Pairwise Features:     |████████▎            | [ 40%]   00:13  -> (00:24 left)
# :Processing Pairwise Features:     |████████▌            | [ 41%]   00:14  -> (00:24 left)
# :Processing Pairwise Features:     |████████▊            | [ 42%]   00:14  -> (00:23 left)
# :Processing Pairwise Features:     |█████████            | [ 43%]   00:15  -> (00:23 left)
# :Processing Pairwise Features:     |█████████▌           | [ 46%]   00:15  -> (00:19 left)
# :Processing Pairwise Features:     |██████████           | [ 48%]   00:15  -> (00:13 left)
# :Processing Pairwise Features:     |██████████▋          | [ 51%]   00:16  -> (00:13 left)
# :Processing Pairwise Features:     |██████████▉          | [ 52%]   00:17  -> (00:16 left)
# :Processing Pairwise Features:     |███████████▏         | [ 53%]   00:17  -> (00:17 left)
# :Processing Pairwise Features:     |███████████▍         | [ 54%]   00:18  -> (00:16 left)
# :Processing Pairwise Features:     |████████████▍        | [ 59%]   00:18  -> (00:10 left)
# :Processing Pairwise Features:     |████████████▉        | [ 62%]   00:19  -> (00:11 left)
# :Processing Pairwise Features:     |█████████████▍       | [ 64%]   00:20  -> (00:11 left)
# :Processing Pairwise Features:     |█████████████▋       | [ 65%]   00:20  -> (00:12 left)
# :Processing Pairwise Features:     |██████████████       | [ 67%]   00:20  -> (00:11 left)
# :Processing Pairwise Features:     |██████████████▎      | [ 68%]   00:21  -> (00:12 left)
# :Processing Pairwise Features:     |██████████████▊      | [ 70%]   00:22  -> (00:09 left)
# :Processing Pairwise Features:     |███████████████      | [ 72%]   00:22  -> (00:09 left)
# :Processing Pairwise Features:     |███████████████▎     | [ 73%]   00:23  -> (00:10 left)
# :Processing Pairwise Features:     |███████████████▌     | [ 74%]   00:23  -> (00:09 left)
# :Processing Pairwise Features:     |████████████████     | [ 77%]   00:24  -> (00:07 left)
# :Processing Pairwise Features:     |████████████████▎    | [ 78%]   00:24  -> (00:07 left)
# :Processing Pairwise Features:     |████████████████▊    | [ 80%]   00:25  -> (00:06 left)
# :Processing Pairwise Features:     |█████████████████    | [ 81%]   00:25  -> (00:06 left)
# :Processing Pairwise Features:     |█████████████████▎   | [ 83%]   00:26  -> (00:06 left)
# :Processing Pairwise Features:     |██████████████████▏  | [ 86%]   00:26  -> (00:03 left)
# :Processing Pairwise Features:     |██████████████████▉  | [ 90%]   00:26  -> (00:02 left)
# :Processing Pairwise Features:     |███████████████████▍ | [ 93%]   00:27  -> (00:01 left)
# :Processing Pairwise Features:     |███████████████████▋ | [ 94%]   00:27  -> (00:01 left)
# :Processing Pairwise Features:     |████████████████████▍| [ 98%]   00:28  -> (00:00 left)
# :Processing Pairwise Features:     |████████████████████▋| [ 99%]   00:29  -> (00:00 left)
# :Processing Pairwise Features:     |█████████████████████| [100%]   00:29  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:29  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
my_report1.show_html('Report1.html')
